# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
df=pd.read_csv('/content/penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
plt.figure(figsize=(15,8))
df.body_mass_g.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
df["culmen_length_mm"].plot()
df["culmen_depth_mm"].plot()
plt.legend(["culmen_length_mm",'culmen_depth_mm'])

# %%
sns.displot(df.culmen_depth_mm)

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
species_counts = df['species'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Penguin Species')
plt.axis('equal')
# Out:
# (-1.0999999840726766,
#  1.099999669248655,
#  -1.099992652256421,
#  1.0999930049206965)

# %%
df.corr()
# Out:
# <ipython-input-78-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-79-f6412ee67fb3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x=df['species'].value_counts().index, y=df['species'].value_counts())
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(x=df['culmen_length_mm'], y=df['culmen_depth_mm'])
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(x=df['culmen_length_mm'], y=df['culmen_depth_mm'])
plt.show()

# %%
sns.pairplot(df)

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.distplot(df.culmen_length_mm)
plt.show()
# Out:
# <ipython-input-85-6436db350e7b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)

# %% [markdown]
# we cant take mean for replacing Nan values so we woll replace with median

# %%
df['culmen_length_mm'].describe()
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: culmen_length_mm, dtype: float64

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
med=df['culmen_length_mm'].median()
df['culmen_length_mm']=df['culmen_length_mm'].fillna(med)

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %% [markdown]
# its working we will implement this on every column

# %%
sns.distplot(df.culmen_depth_mm)
plt.show()
# Out:
# <ipython-input-90-17a0b8d85467>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_depth_mm)

# %%
med=df['culmen_depth_mm'].median()
df['culmen_depth_mm']=df['culmen_depth_mm'].fillna(med)

# %%
sns.distplot(df.flipper_length_mm)
plt.show()
# Out:
# <ipython-input-92-3f0d9c37e3c6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.flipper_length_mm)

# %%
med=df['flipper_length_mm'].median()
df['flipper_length_mm']=df['flipper_length_mm'].fillna(med)

# %%
sns.distplot(df.body_mass_g)
plt.show()
# Out:
# <ipython-input-94-6c2911e6788a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g)

# %%
med=df['body_mass_g'].median()
df['body_mass_g']=df['body_mass_g'].fillna(med)

# %%
mode_sex = df['sex'].mode()[0]  # Use [0] to get the first mode in case of multiple modes
df['sex'].fillna(mode_sex, inplace=True)

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                  False
# dtype: bool

# %% [markdown]
# perfect

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# we  got a perfect dataset where we cant neglet about outliers

# %%
import pandas as pd
independent_vars = ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm']
dependent_var = 'body_mass_g'
correlation_matrix = df[independent_vars + [dependent_var]].corr()
correlation_with_target = correlation_matrix[dependent_var].drop(dependent_var)
print(correlation_with_target)
# Out:
# culmen_length_mm     0.594925
# culmen_depth_mm     -0.471942
# flipper_length_mm    0.871221
# Name: body_mass_g, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.species = le.fit_transform(df.species)
df.island = le.fit_transform(df.island)
df.sex=le.fit_transform(df.sex)

# %%
df
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
X = df.drop(columns = ['body_mass_g'],axis =1)
X.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  sex
# 0        0       2             39.10             18.7              181.0    2
# 1        0       2             39.50             17.4              186.0    1
# 2        0       2             40.30             18.0              195.0    1
# 3        0       2             44.45             17.3              197.0    2
# 4        0       2             36.70             19.3              193.0    1

# %%
Y=df.body_mass_g
Y
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3      4050.0
# 4      3450.0
#         ...
# 339    4050.0
# 340    4850.0
# 341    5750.0
# 342    5200.0
# 343    5400.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  sex
# 0      0.0     1.0          0.254545         0.666667           0.152542  1.0
# 1      0.0     1.0          0.269091         0.511905           0.237288  0.5
# 2      0.0     1.0          0.298182         0.583333           0.389831  0.5
# 3      0.0     1.0          0.449091         0.500000           0.423729  1.0
# 4      0.0     1.0          0.167273         0.738095           0.355932  0.5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_scaled,Y,test_size = 0.2,random_state=0)

# %%
x_train.shape
# Out:
# (275, 6)

# %%
x_test.shape
# Out:
# (69, 6)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
import pandas as pd
model = DecisionTreeRegressor(criterion='friedman_mse')

def find_best_model_using_gridsearchcv(X, Y):
    algos = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {}
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1, 2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': model,
            'params': {
                'criterion': ['friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X, Y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])

# Assuming you have X and Y defined
result_df = find_best_model_using_gridsearchcv(X, Y)
result_df
# Out:
#                model  best_score  \
# 0  linear_regression    0.793484
# 1              lasso    0.793861
# 2      decision_tree    0.721145
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 2, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'ran...

# %% [markdown]
# **Lasso wins so we will do in lasso**

# %%
from sklearn.linear_model import Lasso
l = Lasso()
l.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_train
# Out:
# 49     4150.0
# 310    4950.0
# 325    5500.0
# 122    3450.0
# 167    4050.0
#         ...
# 323    5500.0
# 192    3950.0
# 117    3775.0
# 47     2975.0
# 172    3600.0
# Name: body_mass_g, Length: 275, dtype: float64

# %%
y_test
# Out:
# 141    3475.0
# 6      3625.0
# 60     3150.0
# 249    5550.0
# 54     2900.0
#         ...
# 229    5150.0
# 298    4750.0
# 21     3600.0
# 246    4100.0
# 291    5000.0
# Name: body_mass_g, Length: 69, dtype: float64

# %%
predictions=l.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 152669.31058551342

# %%
from sklearn.metrics import r2_score


r2 = r2_score(y_test, predictions)
print(f"R-squared (R2) Score: {r2}")
# Out:
# R-squared (R2) Score: 0.7841438595213998
